# %% [markdown]
# # GPU regression test on simulated MERFISH data
#
# **Contributors:** Maxwell Schweiger, Steve Presse, Douglas Shepherd
# douglas.shepherd@asu.edu
#
# This notebook downloads the [StatPhysBio simulation dataset](https://zenodo.org/records/17274305), installs [`merfish3d-analysis`](https://github.com/QI2lab/merfish3d-analysis), and runs the repository's standard simulation regression test unchanged. The test converts the simulated data, creates qi2lab datastores, preprocesses images, decodes RNA, estimates chromatic affines where configured, and scores the results against ground truth.
#
# A CUDA-compatible NVIDIA GPU runtime is required. In Colab, select **Runtime > Change runtime type > GPU** before continuing.

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/QI2lab/merfish3d-analysis/blob/main/examples/notebooks/Simulation_example.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/QI2lab/merfish3d-analysis/blob/main/examples/notebooks/Simulation_example.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# ## Install the repository environment
#
# Clone the repository, install `uv`, and synchronize the package plus its development/test dependencies. Dependency resolution and installation can take several minutes.

# %%
# %%capture
# !git clone https://github.com/QI2lab/merfish3d-analysis.git
# %cd merfish3d-analysis
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# !uv sync --group dev

# %% [markdown]
# ## Download and verify the simulation data
#
# The Zenodo archive is approximately 2.3 GB. This notebook downloads it into `simulation-data`, verifies the published MD5 checksum, extracts it, and configures the test environment. Leave additional free space for the extracted files and temporary datastores created by pytest.

# %%
# !mkdir -p simulation-data
# !curl -L "https://zenodo.org/records/17274305/files/merfish3d_analysis-simulation.zip?download=1" -o simulation-data/merfish3d_analysis-simulation.zip
# !echo "3c415493ca37bd19af14464badc45fae  simulation-data/merfish3d_analysis-simulation.zip" | md5sum --check -
# !unzip -q simulation-data/merfish3d_analysis-simulation.zip -d simulation-data

# %% [markdown]
# ## Cache the default U-FISH model
#
# The test matrix discovers locally cached U-FISH models during collection. Download the default `smfish` weights before starting pytest; otherwise the default-model matrix is skipped. The cache retains the historical filename `v1.0.1-simfish_model.onnx`.

# %%
# !uv run python -c "from ufish.api import UFish; UFish(device='cuda:0').load_weights(weights_file='finetune_models/v1.0.1-simfish_model.onnx')"

# %% [markdown]
# ## Run the standard GPU test
#
# Run the repository test module as-is. It uses CUDA device 0 and covers both simulated dataset variants, all three axial spacings, chromatic-affine estimation enabled and disabled, and paired affine-only and SOFIMA preprocessing. This is a substantial regression matrix and can take a long time.

# %%
# !uv run pytest tests/test_simulation_example_pipeline.py -vv --simulation-data-root simulation-data/merfish3d_analysis-simulation

# %% [markdown]
# ## Optional exhaustive matrix
#
# The standard command skips the longer deconvolution matrix. On a suitable GPU host, enable it with `uv run pytest tests/test_simulation_example_pipeline.py -vv --run-simulation-exhaustive --simulation-data-root simulation-data/merfish3d_analysis-simulation`.
